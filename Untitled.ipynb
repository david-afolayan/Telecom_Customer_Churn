# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 

import plotly.express as px

# %%
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px

# %%
df=pd.read_csv('telecom_customer_churn.csv')

# %%
df.head()
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0  0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1  0003-MKNFE    Male   46      No                     0      Glendale
# 2  0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3  0011-IGKFF    Male   78     Yes                     0      Martinez
# 4  0013-EXCHZ  Female   75     Yes                     0     Camarillo
#
#    Zip Code   Latitude   Longitude  Number of Referrals  ...   Payment Method  \
# 0     93225  34.827662 -118.999073                    2  ...      Credit Card
# 1     91206  34.162515 -118.203869                    0  ...      Credit Card
# 2     92627  33.645672 -117.922613                    0  ...  Bank Withdrawal
# 3     94553  38.014457 -122.115432                    1  ...  Bank Withdrawal
# 4     93010  34.227846 -119.079903                    3  ...      Credit Card
#
# ...

# %%
df.tail()
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents          City  \
# 7038  9987-LUTYD  Female   20      No                     0       La Mesa
# 7039  9992-RRAMN    Male   40     Yes                     0     Riverbank
# 7040  9992-UJOEL    Male   22      No                     0           Elk
# 7041  9993-LHIEB    Male   21     Yes                     0  Solana Beach
# 7042  9995-HOTOH    Male   36     Yes                     0   Sierra City
#
#       Zip Code   Latitude   Longitude  Number of Referrals  ...  \
# 7038     91941  32.759327 -116.997260                    0  ...
# 7039     95367  37.734971 -120.954271                    1  ...
# 7040     95432  39.108252 -123.645121                    0  ...
# 7041     92075  33.001813 -117.263628                    5  ...
# 7042     96125  39.600599 -120.636358                    1  ...
#
#        Payment Method Monthly Charge Total Charges  Total Refunds  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 38 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   object
#  1   Gender                             7043 non-null   object
#  2   Age                                7043 non-null   int64
#  3   Married                            7043 non-null   object
#  4   Number of Dependents               7043 non-null   int64
#  5   City                               7043 non-null   object
#  6   Zip Code                           7043 non-null   int64
#  7   Latitude                           7043 non-null   float64
#  8   Longitude                          7043 non-null   float64
#  9   Number of Referrals                7043 non-null   int64
#  10  Tenure in Months                   7043 non-null   int64
# ...

# %%
for col in df.columns:
    percent_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(percent_missing*100)))
# Out:
# Customer ID - 0%
# Gender - 0%
# Age - 0%
# Married - 0%
# Number of Dependents - 0%
# City - 0%
# Zip Code - 0%
# Latitude - 0%
# Longitude - 0%
# Number of Referrals - 0%
# Tenure in Months - 0%
# Offer - 55%
# Phone Service - 0%
# Avg Monthly Long Distance Charges - 10%
# Multiple Lines - 10%
# Internet Service - 0%
# Internet Type - 22%
# Avg Monthly GB Download - 22%
# Online Security - 22%
# Online Backup - 22%
# Device Protection Plan - 22%
# Premium Tech Support - 22%
# Streaming TV - 22%
# Streaming Movies - 22%
# Streaming Music - 22%
# Unlimited Data - 22%
# Contract - 0%
# Paperless Billing - 0%
# Payment Method - 0%
# Monthly Charge - 0%
# Total Charges - 0%
# Total Refunds - 0%
# Total Extra Data Charges - 0%
# Total Long Distance Charges - 0%
# Total Revenue - 0%
# Customer Status - 0%
# Churn Category - 73%
# Churn Reason - 73%

# %%
df = df.dropna()

# %%
df.drop_duplicates()
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents             City  \
# 2     0004-TLHLJ    Male   50      No                     0       Costa Mesa
# 3     0011-IGKFF    Male   78     Yes                     0         Martinez
# 54    0094-OIFMO  Female   78      No                     1  North Hollywood
# 67    0112-QWPNC    Male   61     Yes                     0         Valyermo
# 77    0125-LZQXK    Male   42      No                     0     Big Oak Flat
# ...          ...     ...  ...     ...                   ...              ...
# 7007  9940-RHLFB  Female   53      No                     0     Sunset Beach
# 7010  9944-HKVVB  Female   55      No                     0        King City
# 7012  9947-OTFQU    Male   65      No                     0           Covina
# 7036  9985-MWVIX  Female   53      No                     0             Hume
# 7039  9992-RRAMN    Male   40     Yes                     0        Riverbank
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 681 entries, 2 to 7039
# Data columns (total 38 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        681 non-null    object
#  1   Gender                             681 non-null    object
#  2   Age                                681 non-null    int64
#  3   Married                            681 non-null    object
#  4   Number of Dependents               681 non-null    int64
#  5   City                               681 non-null    object
#  6   Zip Code                           681 non-null    int64
#  7   Latitude                           681 non-null    float64
#  8   Longitude                          681 non-null    float64
#  9   Number of Referrals                681 non-null    int64
#  10  Tenure in Months                   681 non-null    int64
# ...

# %%
df.drop(columns=["Offer","Phone Service","Number of Dependents","Number of Referrals","Tenure in Months","Total Refunds"], inplace=True)

# %%
df.head()
# Out:
#    Customer ID  Gender  Age Married             City  Zip Code   Latitude  \
# 2   0004-TLHLJ    Male   50      No       Costa Mesa     92627  33.645672
# 3   0011-IGKFF    Male   78     Yes         Martinez     94553  38.014457
# 54  0094-OIFMO  Female   78      No  North Hollywood     91605  34.207295
# 67  0112-QWPNC    Male   61     Yes         Valyermo     93563  34.395830
# 77  0125-LZQXK    Male   42      No     Big Oak Flat     95305  37.818589
#
#      Longitude  Avg Monthly Long Distance Charges Multiple Lines  ...  \
# 2  -117.922613                              33.65             No  ...
# 3  -122.115432                              27.82             No  ...
# 54 -118.400022                              11.59             No  ...
# 67 -117.734568                              39.55            Yes  ...
# 77 -120.256995                              45.92             No  ...
#
#    Paperless Billing   Payment Method  Monthly Charge Total Charges  \
# ...

# %%
#df.sort_values(by=['Age'], inplace=False, ascending=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 681 entries, 2 to 7039
# Data columns (total 32 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        681 non-null    object
#  1   Gender                             681 non-null    object
#  2   Age                                681 non-null    int64
#  3   Married                            681 non-null    object
#  4   City                               681 non-null    object
#  5   Zip Code                           681 non-null    int64
#  6   Latitude                           681 non-null    float64
#  7   Longitude                          681 non-null    float64
#  8   Avg Monthly Long Distance Charges  681 non-null    float64
#  9   Multiple Lines                     681 non-null    object
#  10  Internet Service                   681 non-null    object
# ...

# %%
# Summary statistics for numerical columns
summary_stats = df.describe()

# Summary of the churn status
City_counts = df['City'].value_counts()

# Display the results
print(summary_stats)
print(City_counts)

#32.555828 -124.240051
# Out:
#               Age      Zip Code    Latitude   Longitude  \
# count  681.000000    681.000000  681.000000  681.000000
# mean    49.513950  93432.795888   35.984644 -119.618649
# std     17.842782   1797.498929    2.456799    2.093748
# min     19.000000  90001.000000   32.555828 -124.240051
# 25%     33.000000  92122.000000   33.888560 -121.578701
# 50%     51.000000  93251.000000   35.490705 -119.286833
# 75%     64.000000  95222.000000   37.980057 -117.792202
# max     80.000000  96150.000000   41.962127 -115.431225
#
#        Avg Monthly Long Distance Charges  Avg Monthly GB Download  \
# count                         681.000000               681.000000
# mean                           25.374053                24.904552
# std                            14.408589                18.462952
# min                             1.090000                 2.000000
# 25%                            12.400000                12.000000
# ...

# %%
# Filter out entries with negative monthly charges
negative_monthly_charges = df[df['Monthly Charge'] < 0]

# Display these entries
print(negative_monthly_charges)
# Out:
#      Customer ID  Gender  Age Married          City  Zip Code   Latitude  \
# 694   1024-VRZHF    Male   39     Yes     San Diego     92117  32.825086
# 734   1084-UQCHV    Male   35      No  Angelus Oaks     92305  34.167800
# 3383  4816-LXZYW  Female   51      No    Long Beach     90810  33.819814
# 3561  5047-LHVLY    Male   68      No     San Diego     92121  32.898613
# 4315  6086-ESGRL  Female   53      No          Brea     92821  33.930199
# 4451  6275-YDUVO  Female   62      No         Orosi     93647  36.600185
# 5559  7825-GKXMW  Female   41      No     San Diego     92121  32.898613
# 6236  8818-XYFCQ    Male   39     Yes  Walnut Creek     94598  37.916648
#
#        Longitude  Avg Monthly Long Distance Charges Multiple Lines  ...  \
# 694  -117.199424                              21.58            Yes  ...
# 734  -116.864330                              27.97             No  ...
# 3383 -118.222416                              33.44            Yes  ...
# ...

# %%
# Calculate the churn rate
churn_rate = (df['Customer Status'] == 'Churned').mean()

# Display the churn rate
print(churn_rate)
# Out:
# 1.0

# %%
sns.set(style="whitegrid")

# City Distribution
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='Gender',hue='Gender', palette='viridis')
plt.title('Evaluation of the Most Patronage Gender', size= 20)
plt.xlabel('Gender', size= 15)
plt.ylabel('Count of Gender', size= 14)
plt.show()

# %%
# Age Distribution by Churn Status
plt.figure(figsize=(8, 5))
sns.histplot(data=df, x='Age', hue='Customer Status', multiple='stack', palette='viridis', bins=30)
plt.title('Age Distribution by Customer Status', size= 20)
plt.xlabel('Age', size= 17)
plt.ylabel('Frequency', size= 14)
plt.show()

# %%
# Monthly Charges by Churn Status
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Customer Status', y='Monthly Charge', hue='Customer Status', palette='viridis')
plt.title('Monthly Charges by Customer Status')
plt.xlabel('Customer Status')
plt.ylabel('Monthly Charge')
plt.show()

# %%
# Total Charges by Churn Status
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Customer Status', y='Total Charges', hue= 'Customer Status', palette='viridis')
plt.title('Total Charges by Customer Status')
plt.xlabel('Customer Status')
plt.ylabel('Total Charges')
plt.show()

# %%
sns.regplot(x="Latitude", y="Longitude", data=df, scatter_kws = {"color": "red"},line_kws = {"color": "blue"}).set_title('Latitude vs Longitude')
# Out:
# Text(0.5, 1.0, 'Latitude vs Longitude')

# %%
df_numerized = df


for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name]= df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized
# Out:
#       Customer ID  Gender  Age  Married  City  Zip Code   Latitude  \
# 2               0       1   50        0    78     92627  33.645672
# 3               1       1   78        1   198     94553  38.014457
# 54              2       0   78        0   230     91605  34.207295
# 67              3       1   61        1   366     93563  34.395830
# 77              4       1   42        0    23     95305  37.818589
# ...           ...     ...  ...      ...   ...       ...        ...
# 7007          676       0   53        0   342     90742  33.719221
# 7010          677       0   55        0   156     93930  36.220761
# 7012          678       1   65        0    80     91722  34.097345
# 7036          679       0   53        0   145     93628  36.807595
# 7039          680       1   40        1   283     95367  37.734971
#
#        Longitude  Avg Monthly Long Distance Charges  Multiple Lines  ...  \
# 2    -117.922613                              33.65               0  ...
# ...

# %%
corr_mat = df_numerized.corr()

corr_pairs = corr_mat.unstack()

# Sorting the correlation pairs
sorted_pairs = corr_pairs.sort_values()

# Including only pairs that have a correlation greater than 0.5.
# A correlation coefficient of .50 or larger represents a strong or large correlation.
high_corr = sorted_pairs[(sorted_pairs) > 0.5]  

high_corr
# Out:
# Monthly Charge                     Total Charges                        0.523499
# Total Charges                      Monthly Charge                       0.523499
# Contract                           Total Long Distance Charges          0.551141
# Total Long Distance Charges        Contract                             0.551141
# Monthly Charge                     Streaming Movies                     0.582075
# Streaming Movies                   Monthly Charge                       0.582075
# Streaming TV                       Monthly Charge                       0.619933
# Monthly Charge                     Streaming TV                         0.619933
# Contract                           Total Revenue                        0.657043
# Total Revenue                      Contract                             0.657043
# Total Charges                      Contract                             0.657649
# Contract                           Total Charges                        0.657649
# ...

# %%
correlation_matrix = df_numerized.corr(method = 'pearson')
plt.figure(figsize=(20, 5))
sns.heatmap(correlation_matrix, annot = True)
plt.title("Correlation Matrix for Movies")
plt.xlabel("Movie features")
plt.ylabel("Movie features")
plt.show()

# %%
fig = px.scatter_mapbox(
    df,
   lat="Latitude",
   lon="Longitude",
  # center=("Headquarters": 14.2, ),
    center={"lat":33.645672	, "lon":-117.922613},  # Map will be centered on Brazil
    width=1000,
    height=600,
    hover_data=["Internet Type"],  # Display price when hovering mouse over house
color="Internet Type",)

fig.update_layout(mapbox_style="open-street-map")

fig.show()

# %%
px.bar(df, x="Age", y="Total Revenue", color="Age",
      title="Evaluation of Total Revenue by Age")

# %%
sns.set(style="whitegrid")

# City Distribution
plt.figure(figsize=(5, 2.5))
sns.countplot(data=df, x='Married',hue='Married', palette='viridis')
plt.title('Count of by Marital status (Married or not)', size= 20)
plt.xlabel('Married', size= 15)
plt.ylabel('Count', size= 14)
plt.show()
